# %%
print("Hello World")

# %%
# %sql
SELECT "Hello World from SQL"

# %% [markdown]
# # My first Notebook
# - switching between languages and markdown
# - connecting to cluster

# %%
# %run ./includes/Setup

# %%
print(name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls("/databricks-datasets/")
display(files)
